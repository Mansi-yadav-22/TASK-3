# %%
def add_contact():
  name = input("Enter name: ")
  phone = input("Enter phone number: ")
  email = input("Enter email address: ")
  contacts.append({"name": name, "phone": phone, "email": email})
  print("Contact added successfully!")

def view_contacts():
  if not contacts:
    print("No contacts found.")
  else:
    for i, contact in enumerate(contacts):
      print(f"{i+1}. Name: {contact['name']}, Phone: {contact['phone']}, Email: {contact['email']}")

def edit_contact():
  view_contacts()
  try:
    index = int(input("Enter the number of the contact to edit: ")) - 1
    if 0 <= index < len(contacts):
      contact = contacts[index]
      print(f"Editing contact: {contact['name']}")
      contact['name'] = input("Enter new name (leave blank to keep current): ") or contact['name']
      contact['phone'] = input("Enter new phone number (leave blank to keep current): ") or contact['phone']
      contact['email'] = input("Enter new email address (leave blank to keep current): ") or contact['email']
      print("Contact updated successfully!")
    else:
      print("Invalid contact number.")
  except ValueError:
    print("Invalid input. Please enter a number.")

def delete_contact():
  view_contacts()
  try:
    index = int(input("Enter the number of the contact to delete: ")) - 1
    if 0 <= index < len(contacts):
      del contacts[index]
      print("Contact deleted successfully!")
    else:
      print("Invalid contact number.")
  except ValueError:
    print("Invalid input. Please enter a number.")


contacts = []

while True:
  print("\nContact Management Menu:")
  print("1. Add Contact")
  print("2. View Contacts")
  print("3. Edit Contact")
  print("4. Delete Contact")
  print("5. Exit")

  choice = input("Enter your choice: ")

  if choice == '1':
    add_contact()
  elif choice == '2':
    view_contacts()
  elif choice == '3':
    edit_contact()
  elif choice == '4':
    delete_contact()
  elif choice == '5':
    print("Exiting program...")
    break
  else:
    print("Invalid choice. Please try again.")
# Out:
# Contact Management Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Edit Contact
# 4. Delete Contact
# 5. Exit
# Enter your choice: 1
# Enter name: Pearl
# Enter phone number: 9876543210
# Enter email address: abc@gmail.com
# Contact added successfully!
#
# Contact Management Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Edit Contact
# 4. Delete Contact
# 5. Exit
# Enter your choice: 2
# 1. Name: Pearl, Phone: 9876543210, Email: abc@gmail.com
#
# Contact Management Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Edit Contact
# 4. Delete Contact
# 5. Exit
# Enter your choice: 3
# 1. Name: Pearl, Phone: 9876543210, Email: abc@gmail.com
# Enter the number of the contact to edit: 1
# Editing contact: Pearl
# Enter new name (leave blank to keep current): Riya
# Enter new phone number (leave blank to keep current):
# Enter new email address (leave blank to keep current):
# Contact updated successfully!
#
# Contact Management Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Edit Contact
# 4. Delete Contact
# 5. Exit
# Enter your choice: 4
# 1. Name: Riya, Phone: 9876543210, Email: abc@gmail.com
# Enter the number of the contact to delete: 1
# Contact deleted successfully!
#
# Contact Management Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Edit Contact
# 4. Delete Contact
# 5. Exit
# Enter your choice: 5
# Exiting program...
